# %%
import pandas as pd

df = pd.read_excel('./data/数据2.12.xlsx',header=1)

df.head(5)

df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', '年龄', '性别', '职业', '身高', '体重', 'BMI', '教育水平',
#        '是否吸烟', '是否饮酒', '症状持续时间', '主要症状', '疼痛频率', '是否有放射痛', '是否与进食有关',
#        '是否合并高血压', '是否合并高血脂', '是否合并糖尿病', '是否焦虑/抑郁', '是否既往腹部手术史', '胆囊壁是否增厚',
#        '最大结石直径', '结石数量', '结石位置', '胆总管直径', '术后胆总管', '是否有脂肪肝', '胆囊是否萎缩', '手术时间',
#        '预估出血量', '是否术中并发症', '术后病理诊断', '谷丙转氨酶', '谷草转氨酶', '碱性磷酸酶', '谷氨酰转肽酶',
#        '总胆红素', '总胆汁酸', '血淀粉酶', '总胆固醇', '甘油三酯', '甲胎蛋白', 'CA199', '是否发生PCS',
#        'PCS发生时间', 'PCS症状类型'],
#       dtype='object')
